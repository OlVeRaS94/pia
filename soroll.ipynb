# %%
def el_contaminar(filename, p):
	#obri la imatge
	original=Image.open(filename)

	#convertim a ndarray
M_original=np-array(original)

#comprovem les dimensions de la imatge
print(f"Imatge {filename} de dimensions {M_original.shape}")

#contaminem els pixels  (les vores no)
plt.imshow(M_original)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
# ----> 5    "execution_count": null,
#       6    "id": "56d55aee",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "# Importar librerías necesarias\n",
#      11     "import numpy as np\n",
#      12     "from PIL import Image\n",
#      13     "import random\n",
#      14     "import os\n",
#      15     "\n",
#      16     "# Función para añadir ruido a la imagen\n",
#      17     "def añadir_ruido(imagen_path, porcentaje_ruido):\n",
#      18     "    # Cargar la imagen usando PIL\n",
#      19     "    imagen = Image.open(imagen_path)\n",
#      20     "\n",
#      21     "    # Convertir la imagen a un array de NumPy\n",
#      22     "    img_array = np.array(imagen)\n",
# ...

# %%
el_contaminar('arroz002.jpg',5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 el_contaminar('arroz002.jpg',5)
#
# Cell In[2], line 3, in el_contaminar(filename, p)
#       1 def el_contaminar(filename, p):
#       2 	#obri la imatge
# ----> 3 	original=Image.open(filename)
#
# NameError: name 'Image' is not defined
